# %%
from IPython.display import Image

# %% [markdown]
# # installation et mise en place de MongoDB Community Edition en local

# %%
Image("snaps/installation_mongo/install1.png")

# %%
Image("snaps/installation_mongo/install3.jpg")

# %%
Image("snaps/installation_mongo/install4.jpg")

# %% [markdown]
# # Lancer mongodb en local

# %%
Image("snaps/installation_mongo/ouvrirMongoDB.png")

# %%
Image("snaps/installation_mongo/ouvrirMongo2.png")

# %% [markdown]
# # Ouvrir mongo shell et affiche tous les data base

# %%
Image("snaps/installation_mongo/mongod.png")

# %%
Image("snaps/installation_mongo/ouvrirMongoShell.png")
